# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/MyDrive")
# !pwd
# Out:
# /content/gdrive/MyDrive

# %%
import os
os.chdir("/content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/")
# !pwd
# Out:
# /content/gdrive/MyDrive/Yolo-Vehicle-Counter
# --2023-02-24 22:10:50--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  19.4MB/s    in 13s
#
# 2023-02-24 22:11:04 (17.7 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# mv: cannot move 'yolov3.weights' to '/content/gdrive/Yolo-Vehicle-Counter/yolo-coco': No such file or directory

# %%
# !pip3 install opencv-python==3.4.8.29
# !pip3 install imutils
# !pip3 install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.3/28.3 MB 48.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
os.chdir("/content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/")
# !pwd
# !python3 /content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/yolo_ds.py --input /content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/bridge.mp4 --output /content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/bridgeOut_C_0.7_3.avi --yolo yolo-coco
# Out:
# /content/gdrive/MyDrive/Yolo-Vehicle-Counter
# 2023-02-26 21:20:24.189580: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-26 21:20:25.347522: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
# !python3 /content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/yolo_ds.py --input /content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/CarsOnHighway.mp4 --output /content/gdrive/MyDrive/Yolo-DS-Vehicle-Counter/CarsOnHighwayOut2_C0.7_3.avi --yolo yolo-coco
